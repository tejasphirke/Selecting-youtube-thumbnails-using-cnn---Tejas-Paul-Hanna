# %%
import os
import subprocess
import pandas as pd
from pytube import YouTube

def download_video(url, output_path):
    yt = YouTube(url)
    video_stream = yt.streams.filter(file_extension="mp4", progressive=True).first()
    video_stream.download(output_path)
    return os.path.join(output_path, video_stream.default_filename)

def extract_frames(video_path, output_path, frame_interval=10):
    if not os.path.exists(output_path):
        os.makedirs(output_path)

    output_pattern = os.path.join(output_path, "frame_%04d.jpg")

    cmd = [
        "ffmpeg",
        "-i", video_path,
        "-vf", f"fps=1/{frame_interval}",
        output_pattern
    ]

    subprocess.run(cmd)

if __name__ == "__main__":
    # Load your dataset with YouTube URLs
    dataset_path = r"T:\sem_3\Neural Networks and Deep Learning\project\NNDL\good_news.csv"
    df = pd.read_csv(dataset_path)

    # Specify the base output directory for frames
    base_output_directory = r"T:\sem_3\Neural Networks and Deep Learning\project\NNDL\good_news_data_img\good_news_data_images"


    # Iterate through each row in the dataset
    for index, row in df.iterrows():
        youtube_url = row["video_url"]

        try:
            video_path = download_video(youtube_url, base_output_directory)

            # Create a unique output folder for each video
            video_id = youtube_url.split("v=")[1]
            output_directory = os.path.join(base_output_directory, f"video_{video_id}")
            
            extract_frames(video_path, output_directory)

            print(f"Processing video {index + 1}/{len(df)}: {youtube_url}")
        except Exception as e:
            print(f"Error processing video {index + 1}/{len(df)}: {youtube_url}")
            print(f"Error message: {str(e)}")
# Out:
# Processing video 1/265: https://www.youtube.com/watch?v=9qpMuFrTEKo
# Processing video 2/265: https://www.youtube.com/watch?v=F5pgG1M_h_U
# Error processing video 3/265: https://www.youtube.com/watch?v=NDjNX3nEfYo
# Error message: NDjNX3nEfYo is age restricted, and can't be accessed without logging in.
# Processing video 4/265: https://www.youtube.com/watch?v=5pvaLA4X9GE
# Processing video 5/265: https://www.youtube.com/watch?v=vq0L_4y-hVs
# Processing video 6/265: https://www.youtube.com/watch?v=oilZ1hNZPRM
# Error processing video 7/265: https://www.youtube.com/watch?v=VQLi2GYVULc
# Error message: VQLi2GYVULc is age restricted, and can't be accessed without logging in.
# Processing video 8/265: https://www.youtube.com/watch?v=Eg08rJGKjtA
# Processing video 9/265: https://www.youtube.com/watch?v=JNvpcGV1frQ
# Processing video 10/265: https://www.youtube.com/watch?v=cqvVL8IurMw
# Error processing video 11/265: https://www.youtube.com/watch?v=o1zIgTwENPg
# Error message: o1zIgTwENPg is age restricted, and can't be accessed without logging in.
# Processing video 12/265: https://www.youtube.com/watch?v=IweS2CPSnbI
# Error processing video 13/265: https://www.youtube.com/watch?v=TXdKrtmexWU
# Error message: TXdKrtmexWU is age restricted, and can't be accessed without logging in.
# Processing video 14/265: https://www.youtube.com/watch?v=KjBMkS0TT4c
# Error processing video 15/265: https://www.youtube.com/watch?v=XCYq3rltnVI
# Error message: XCYq3rltnVI is age restricted, and can't be accessed without logging in.
# Error processing video 16/265: https://www.youtube.com/watch?v=4Mr3WL9zD_o
# Error message: 4Mr3WL9zD_o is age restricted, and can't be accessed without logging in.
# Error processing video 17/265: https://www.youtube.com/watch?v=LypyAmqvkZk
# Error message: LypyAmqvkZk is age restricted, and can't be accessed without logging in.
# Processing video 18/265: https://www.youtube.com/watch?v=6DLU4Gih0gY
# Processing video 19/265: https://www.youtube.com/watch?v=3GwU4GKzLXY
# Error processing video 20/265: https://www.youtube.com/watch?v=QHY2ydqC6D4
# Error message: QHY2ydqC6D4 is age restricted, and can't be accessed without logging in.
# Error processing video 21/265: https://www.youtube.com/watch?v=y0CHsK2rUgA
# Error message: y0CHsK2rUgA is age restricted, and can't be accessed without logging in.
# Error processing video 22/265: https://www.youtube.com/watch?v=UZsu1OQ-hFI
# Error message: UZsu1OQ-hFI is age restricted, and can't be accessed without logging in.
# Error processing video 23/265: https://www.youtube.com/watch?v=yoE8VTw7Y-o
# Error message: yoE8VTw7Y-o is age restricted, and can't be accessed without logging in.
# Error processing video 24/265: https://www.youtube.com/watch?v=kT7SlqL474Q
# Error message: kT7SlqL474Q is age restricted, and can't be accessed without logging in.
# Error processing video 25/265: https://www.youtube.com/watch?v=-Fb48tivB-0
# Error message: -Fb48tivB-0 is age restricted, and can't be accessed without logging in.
# Error processing video 26/265: https://www.youtube.com/watch?v=SPMSde2WxGc
# Error message: SPMSde2WxGc is age restricted, and can't be accessed without logging in.
# Processing video 27/265: https://www.youtube.com/watch?v=mvUClDPFsGA
# Error processing video 28/265: https://www.youtube.com/watch?v=2Py-MLiX_0g
# Error message: 2Py-MLiX_0g is age restricted, and can't be accessed without logging in.
# Error processing video 29/265: https://www.youtube.com/watch?v=s9HT6aSstDs
# Error message: s9HT6aSstDs is age restricted, and can't be accessed without logging in.
# Error processing video 30/265: https://www.youtube.com/watch?v=EYsN1rHi1mo
# Error message: EYsN1rHi1mo is age restricted, and can't be accessed without logging in.
# Error processing video 31/265: https://www.youtube.com/watch?v=CpY9kWTmdIg
# Error message: CpY9kWTmdIg is age restricted, and can't be accessed without logging in.
# Error processing video 32/265: https://www.youtube.com/watch?v=qDRh2Aw2maw
# Error message: qDRh2Aw2maw is age restricted, and can't be accessed without logging in.
# Error processing video 33/265: https://www.youtube.com/watch?v=DAp6gXocqUo
# Error message: DAp6gXocqUo is age restricted, and can't be accessed without logging in.
# Processing video 34/265: https://www.youtube.com/watch?v=qWurkjlq8Nw
# Processing video 35/265: https://www.youtube.com/watch?v=MiUIs8kgQX8
# Processing video 36/265: https://www.youtube.com/watch?v=e8_6NEnS41A
# Error processing video 37/265: https://www.youtube.com/watch?v=xBJ-fE_u74U
# Error message: xBJ-fE_u74U is age restricted, and can't be accessed without logging in.
# Error processing video 38/265: https://www.youtube.com/watch?v=sPu0j7towPA
# Error message: sPu0j7towPA is age restricted, and can't be accessed without logging in.
# Error processing video 39/265: https://www.youtube.com/watch?v=ECNZ2BHkszY
# Error message: ECNZ2BHkszY is age restricted, and can't be accessed without logging in.
# Error processing video 40/265: https://www.youtube.com/watch?v=N8zF9tAzu74
# Error message: N8zF9tAzu74 is age restricted, and can't be accessed without logging in.
# Processing video 41/265: https://www.youtube.com/watch?v=-sd-780SYAs
# Error processing video 42/265: https://www.youtube.com/watch?v=s8PoccIlGes
# Error message: s8PoccIlGes is age restricted, and can't be accessed without logging in.
# Error processing video 43/265: https://www.youtube.com/watch?v=44mQlSwBTW8
# Error message: 44mQlSwBTW8 is age restricted, and can't be accessed without logging in.
# Error processing video 44/265: https://www.youtube.com/watch?v=NEXwTu8MN3g
# Error message: NEXwTu8MN3g is age restricted, and can't be accessed without logging in.
# Error processing video 45/265: https://www.youtube.com/watch?v=9GzV0SGzTb8
# Error message: 9GzV0SGzTb8 is age restricted, and can't be accessed without logging in.
# Error processing video 46/265: https://www.youtube.com/watch?v=11s7JwQ2Z50
# Error message: 11s7JwQ2Z50 is age restricted, and can't be accessed without logging in.
# Error processing video 47/265: https://www.youtube.com/watch?v=dbNDmY1-vSs
# Error message: dbNDmY1-vSs is age restricted, and can't be accessed without logging in.
# Error processing video 48/265: https://www.youtube.com/watch?v=HPAd81AzqXg
# Error message: HPAd81AzqXg is age restricted, and can't be accessed without logging in.
# Error processing video 49/265: https://www.youtube.com/watch?v=cDW5Q7_T7mc
# Error message: cDW5Q7_T7mc is age restricted, and can't be accessed without logging in.
# Processing video 50/265: https://www.youtube.com/watch?v=i43WrOwwgpQ
# Processing video 51/265: https://www.youtube.com/watch?v=t7GhemGAZXs
# Processing video 52/265: https://www.youtube.com/watch?v=iS0QuyyiT6M
# Error processing video 53/265: https://www.youtube.com/watch?v=daVsZJpEpCM
# Error message: daVsZJpEpCM is age restricted, and can't be accessed without logging in.
# Processing video 54/265: https://www.youtube.com/watch?v=nFqU8W7qeS8
# Error processing video 55/265: https://www.youtube.com/watch?v=4bi3YyQEnVU
# Error message: 4bi3YyQEnVU is age restricted, and can't be accessed without logging in.
# Processing video 56/265: https://www.youtube.com/watch?v=43diGN3pR8U
# Processing video 57/265: https://www.youtube.com/watch?v=Vkamgm8y7CU
# Processing video 58/265: https://www.youtube.com/watch?v=qjePTm9uNng
# Processing video 59/265: https://www.youtube.com/watch?v=078LvtHRm98
# Error processing video 60/265: https://www.youtube.com/watch?v=j_XPD1boH0g
# Error message: j_XPD1boH0g is age restricted, and can't be accessed without logging in.
# Processing video 61/265: https://www.youtube.com/watch?v=BwD1_KjYW9w
# Processing video 62/265: https://www.youtube.com/watch?v=tggNvNykBPg
# Processing video 63/265: https://www.youtube.com/watch?v=I1TNrWlGloc
# Error processing video 64/265: https://www.youtube.com/watch?v=Q51EkXNDnD0
# Error message: Q51EkXNDnD0 is age restricted, and can't be accessed without logging in.
# Processing video 65/265: https://www.youtube.com/watch?v=EKSktq30pK4
# Processing video 66/265: https://www.youtube.com/watch?v=wJpp1sfWcVU
# Processing video 67/265: https://www.youtube.com/watch?v=1J1PYVDf9z4
# Error processing video 68/265: https://www.youtube.com/watch?v=Kb2vYvqC6ro
# Error message: Kb2vYvqC6ro is age restricted, and can't be accessed without logging in.
# Processing video 69/265: https://www.youtube.com/watch?v=O5sfmO-jDwU
# Processing video 70/265: https://www.youtube.com/watch?v=AVwVfrC9XgI
# Processing video 71/265: https://www.youtube.com/watch?v=WGMHudIW6Dw
# Processing video 72/265: https://www.youtube.com/watch?v=7DL-IC7JDW8
# Error processing video 73/265: https://www.youtube.com/watch?v=Z66QGRScl2I
# Error message: Z66QGRScl2I is age restricted, and can't be accessed without logging in.
# Processing video 74/265: https://www.youtube.com/watch?v=fdzR7Ew-Wlw
# Processing video 75/265: https://www.youtube.com/watch?v=xR8XNfdARxk
# Processing video 76/265: https://www.youtube.com/watch?v=NW5NFSXDz7g
# Processing video 77/265: https://www.youtube.com/watch?v=ZTtdR94f_7A
# Error processing video 78/265: https://www.youtube.com/watch?v=iwOsh-jg4zA
# Error message: iwOsh-jg4zA is age restricted, and can't be accessed without logging in.
# Processing video 79/265: https://www.youtube.com/watch?v=kpQG89oxEVo
# Processing video 80/265: https://www.youtube.com/watch?v=vG-g1I55_WE
# Error processing video 81/265: https://www.youtube.com/watch?v=qODLKGy8kqo
# Error message: qODLKGy8kqo is age restricted, and can't be accessed without logging in.
# Processing video 82/265: https://www.youtube.com/watch?v=cdv2au39Z1s
# Error processing video 83/265: https://www.youtube.com/watch?v=2BXzNu3_6fE
# Error message: 2BXzNu3_6fE is age restricted, and can't be accessed without logging in.
# Error processing video 84/265: https://www.youtube.com/watch?v=MQrpXEF3pZE
# Error message: MQrpXEF3pZE is age restricted, and can't be accessed without logging in.
# Error processing video 85/265: https://www.youtube.com/watch?v=0bObf0RfCBQ
# Error message: 0bObf0RfCBQ is age restricted, and can't be accessed without logging in.
# Processing video 86/265: https://www.youtube.com/watch?v=aAFB4bAis0g
# Error processing video 87/265: https://www.youtube.com/watch?v=5UTqsWtz1po
# Error message: 5UTqsWtz1po is age restricted, and can't be accessed without logging in.
# Processing video 88/265: https://www.youtube.com/watch?v=f-MHO_MUbsI
# Processing video 89/265: https://www.youtube.com/watch?v=EIVsqtJiOAU
# Processing video 90/265: https://www.youtube.com/watch?v=uz_CX0h2Uh8
# Processing video 91/265: https://www.youtube.com/watch?v=H9gEXHshaqI
# Processing video 92/265: https://www.youtube.com/watch?v=ibomw8Ea1Vk
# Processing video 93/265: https://www.youtube.com/watch?v=X6xn2vt1Fj0
# Processing video 94/265: https://www.youtube.com/watch?v=wflq785VBks
# Error processing video 95/265: https://www.youtube.com/watch?v=_CkAiq_gJ0A
# Error message: _CkAiq_gJ0A is age restricted, and can't be accessed without logging in.
# Processing video 96/265: https://www.youtube.com/watch?v=0taGg9xSNcU
# Processing video 97/265: https://www.youtube.com/watch?v=XUI0Yxqdk8g
# Processing video 98/265: https://www.youtube.com/watch?v=mgqbQxngHrY
# Processing video 99/265: https://www.youtube.com/watch?v=L5anT2daTgc
# Error processing video 100/265: https://www.youtube.com/watch?v=PA8q2-niyd8
# Error message: PA8q2-niyd8 is age restricted, and can't be accessed without logging in.
# Error processing video 101/265: https://www.youtube.com/watch?v=t3EgC_z8DV8
# Error message: t3EgC_z8DV8 is age restricted, and can't be accessed without logging in.
# Processing video 102/265: https://www.youtube.com/watch?v=1NExJOx-G_U
# Processing video 103/265: https://www.youtube.com/watch?v=15TMkxU_YJo
# Processing video 104/265: https://www.youtube.com/watch?v=IuNalIxb1X4
