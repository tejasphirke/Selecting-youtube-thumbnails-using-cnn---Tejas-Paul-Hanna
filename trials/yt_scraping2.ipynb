# %%
import csv
import json
from googleapiclient.discovery import build
import pandas as pd
import numpy as np

# %%
def initialize_youtube_api(api_key):
    return build('youtube', 'v3', developerKey=api_key)

# %%
def get_channel_name(youtube, channel_id):
    request = youtube.channels().list(
        part="snippet",
        id=channel_id
    )
    response = request.execute()

    return response['items'][0]['snippet']['title']

# %%
def get_videos_from_channel(youtube, channel_id, max_results=70):
    channel_name = get_channel_name(youtube, channel_id)

    request = youtube.search().list(
        part="snippet",
        channelId=channel_id,
        type="video",
        order="date",
        maxResults=max_results
    )
    response = request.execute()

    videos = []

    for item in response['items']:
        video_id = item['id']['videoId']
        video_info = get_video_info(youtube, video_id, channel_name)
        videos.append(video_info)

    return videos

# %%
def get_video_info(youtube, video_id, channel_name):
    request = youtube.videos().list(
        part="snippet,statistics,contentDetails",
        id=video_id
    )
    response = request.execute()

    video_info = {
        "channel_name": channel_name,
        "published_date": response['items'][0]['snippet']['publishedAt'],
        "view_count": response['items'][0]['statistics']['viewCount'],
        "video_length": response['items'][0]['contentDetails']['duration'],
        "video_url": f"https://www.youtube.com/watch?v={video_id}",
        "title": response['items'][0]['snippet']['title']
    }

    return video_info

# %%
def scrape_videos(api_key, channel_ids, max_results=50):
    youtube = initialize_youtube_api(api_key)

    all_videos = []

    for channel_id in channel_ids:
        videos = get_videos_from_channel(youtube, channel_id, max_results)
        all_videos.extend(videos)

    return all_videos

# %%
def save_to_csv(data, filename='youtube_data.csv'):
    with open(filename, 'w', newline='', encoding='utf-8') as csv_file:
        fieldnames = ['channel_name', 'published_date', 'view_count', 'video_length', 'video_url', 'title']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

        writer.writeheader()
        for video in data:
            writer.writerow(video)

if __name__ == "__main__":

    api_key = 'AIzaSyBVVLaf0whpkVGJF82LWC0DVPRfkyasS28'

    channel_ids = [
'UCorcjV3oNf1G8cPL8fUeJCw', 'UCltiBg8J6gmkseoeMCxSh8g', 'UCVaXclURQZlakiTMzuwHvRw', 'UCAlZQ3nGsE9BbP380qiy1dw']
    videos = scrape_videos(api_key, channel_ids)

    # Save the result to a CSV file
    save_to_csv(videos, 'df1.csv')

# %%
def save_to_csv(data, filename='youtube_data.csv'):
    with open(filename, 'w', newline='', encoding='utf-8') as csv_file:
        fieldnames = ['channel_name', 'published_date', 'view_count', 'video_length', 'video_url', 'title']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

        writer.writeheader()
        for video in data:
            writer.writerow(video)

if __name__ == "__main__":

    api_key = 'AIzaSyCG1jfdNI9VaIZC0RNHnGQLK1fQfq7VUlY'

    channel_ids = [
'UCDvJcb8Adv-_bOrtnRLmiDw', 'UCT2lL0nVVQWU4L4NUvjCZSA', 'UCVWfPMigxyv9-94F_o_nFpg', 'UC8J6Znx5R22-F2zLTRXye6g', 'UC7Vw6oq2LCbzAhdxF_UcIWg',]
    videos = scrape_videos(api_key, channel_ids)

    # Save the result to a CSV file
    save_to_csv(videos, 'yt.csv')

# %%
'UCorcjV3oNf1G8cPL8fUeJCw', 'UCltiBg8J6gmkseoeMCxSh8g', 'UCVaXclURQZlakiTMzuwHvRw', 'UCAlZQ3nGsE9BbP380qiy1dw'

# %%
df2 = pd.read_csv('df.csv')
df3 = pd.read_csv('df1.csv')
df4 = pd.read_csv('yt.csv')
dfs = pd.concat([df2,df3,df4])

# %%
dfs.to_csv('bad_news.csv')

# %%
df2 = pd.read_csv('data1.csv')
df3 = pd.read_csv('data2.csv')
df4 = pd.read_csv('data3.csv')
df5 = pd.read_csv('data4.csv')
df6 = pd.read_csv('data5.csv')
df7 = pd.read_csv('data0.csv')
df8 = pd.read_csv('data7.csv')
df9 = pd.read_csv('data8.csv')
df10 = pd.read_csv('df.csv')
df11 = pd.read_csv('df1.csv')
df12 = pd.read_csv('df2.csv')
df13 = pd.read_csv('df3.csv')
df14 = pd.read_csv('df4.csv')
df15 = pd.read_csv('df5.csv')
df16 = pd.read_csv('df6.csv')
df17 = pd.read_csv('yt.csv')
df18 = pd.read_csv('yt1.csv')
df19 = pd.read_csv('yt2.csv')
df20 = pd.read_csv('yt3.csv')
df21 = pd.read_csv('yt4.csv')
df22 = pd.read_csv('yt5.csv')
df23 = pd.read_csv('yt6.csv')

# %%
dfs = pd.concat([df2,df3,df4,df5,df6,df8,df9,df10,df11, df7,
                 df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23])

# %%
dfs
# Out:
#            channel_name        published_date  view_count  \
# 0          About To Eat  2023-04-19T21:00:14Z      124447
# 1          About To Eat  2023-04-18T21:34:00Z       74472
# 2          About To Eat  2023-04-17T21:03:14Z       49114
# 3          About To Eat  2023-04-15T15:41:45Z      113796
# 4          About To Eat  2023-04-13T15:36:12Z    14985878
# ..                  ...                   ...         ...
# 189  Internet Historian  2017-01-27T09:14:01Z     4029492
# 190  Internet Historian  2017-01-21T04:31:38Z    12108895
# 191  Internet Historian  2017-01-15T21:14:45Z     4934960
# 192  Internet Historian  2017-01-14T03:12:16Z     6376799
# 193  Internet Historian  2017-01-11T09:15:03Z     6799467
#
#                                        video_url  \
# 0    https://www.youtube.com/watch?v=VG7rsyv5oYo
# 1    https://www.youtube.com/watch?v=NFRrJyDvwzg
# 2    https://www.youtube.com/watch?v=VSken1GZWb4
# 3    https://www.youtube.com/watch?v=H-VmxmT27sg
# ...

# %%
dfs.to_csv('final_yt_data.csv')
